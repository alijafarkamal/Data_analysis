# %%
var = [5,6,7,8]
print(var)
# Out:
# [5, 6, 7, 8]

# %%
from urllib.request import urlretrieve

# %%
italy_covid_url = 'https://gist.githubusercontent.com/aakashns/f6a004fa20c84fec53262f9a8bfee775/raw/f309558b1cf5103424cef58e2ecb8704dcd4d74c/italy-covid-daywise.csv'

urlretrieve(italy_covid_url, 'italy-covid-daywise.csv')
# Out:
# ('italy-covid-daywise.csv', <http.client.HTTPMessage at 0x20351cdda50>)

# %%
import pandas as pd

# %%
 covid_info = pd.read_csv('italy-covid-daywise.csv')

# %%
type(covid_info)
# Out:
# pandas.core.frame.DataFrame

# %%
 covid_info
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %%
covid_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        248 non-null    object
#  1   new_cases   248 non-null    float64
#  2   new_deaths  248 non-null    float64
#  3   new_tests   135 non-null    float64
# dtypes: float64(3), object(1)
# memory usage: 7.9+ KB

# %%
covid_info.describe()
# Out:
#          new_cases  new_deaths     new_tests
# count   248.000000  248.000000    135.000000
# mean   1094.818548  143.133065  31699.674074
# std    1554.508002  227.105538  11622.209757
# min    -148.000000  -31.000000   7841.000000
# 25%     123.000000    3.000000  25259.000000
# 50%     342.000000   17.000000  29545.000000
# 75%    1371.750000  175.250000  37711.000000
# max    6557.000000  971.000000  95273.000000

# %%
covid_info.columns
# Out:
# Index(['date', 'new_cases', 'new_deaths', 'new_tests'], dtype='object')

# %%
covid_info.shape
# Out:
# (248, 4)

# %%
# Pandas format is simliar to this
covid_data_dict = {
    'date':       ['2020-08-30', '2020-08-31', '2020-09-01', '2020-09-02', '2020-09-03'],
    'new_cases':  [1444, 1365, 996, 975, 1326],
    'new_deaths': [1, 4, 6, 8, 6],
    'new_tests': [53541, 42583, 54395, None, None]
}

# %%
covid_data_dict['new_cases']
# Out:
# [1444, 1365, 996, 975, 1326]

# %%
type(covid_data_dict)
# Out:
# dict

# %%
covid_info['new_cases'][246]
# Out:
# 975.0

# %%
 covid_info.at[240, 'new_tests']
# Out:
# 57640.0

# %%
covid_info_copy = covid_info.copy(['new_cases'])

# %%
covid_info_copy
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %%
covid_info_copy = covid_info[['date']]

# %%
 covid_info.loc[
# Out:
#            date  new_cases  new_deaths  new_tests
# 0    2019-12-31        0.0         0.0        NaN
# 1    2020-01-01        0.0         0.0        NaN
# 2    2020-01-02        0.0         0.0        NaN
# 3    2020-01-03        0.0         0.0        NaN
# 4    2020-01-04        0.0         0.0        NaN
# ..          ...        ...         ...        ...
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 245  2020-09-01      996.0         6.0    54395.0
# 246  2020-09-02      975.0         8.0        NaN
# 247  2020-09-03     1326.0         6.0        NaN
#
# [248 rows x 4 columns]

# %%
covid_info.loc[5]
# Out:
# date          2020-01-05
# new_cases            0.0
# new_deaths           0.0
# new_tests            NaN
# Name: 5, dtype: object

# %%
covid_info.new_tests.first_valid_index()
# Out:
# 111

# %%
covid_info.loc[108:113]
# Out:
#            date  new_cases  new_deaths  new_tests
# 108  2020-04-17     3786.0       525.0        NaN
# 109  2020-04-18     3493.0       575.0        NaN
# 110  2020-04-19     3491.0       480.0        NaN
# 111  2020-04-20     3047.0       433.0     7841.0
# 112  2020-04-21     2256.0       454.0    28095.0
# 113  2020-04-22     2729.0       534.0    44248.0

# %%
covid_info.sample(10)
# Out:
#            date  new_cases  new_deaths  new_tests
# 38   2020-02-07        0.0         0.0        NaN
# 40   2020-02-09        0.0         0.0        NaN
# 72   2020-03-12     2313.0       196.0        NaN
# 145  2020-05-24      669.0       119.0    34206.0
# 25   2020-01-25        0.0         0.0        NaN
# 20   2020-01-20        0.0         0.0        NaN
# 91   2020-03-31     4050.0       810.0        NaN
# 158  2020-06-06      518.0        85.0    34036.0
# 185  2020-07-03      201.0        30.0    25680.0
# 114  2020-04-23     3370.0       437.0    37083.0

# %%
total_cases = covid_info.new_cases.sum()

# %%
total_cases
# Out:
# 271515.0

# %%
death_rate = round((covid_info.new_deaths.sum()/covid_info.new_cases.sum())*100,2)

# %%
death_rate
# Out:
# 13.07

# %%
high_new_cases = covid_info.new_cases>1000

# %%
covid_info[high_new_cases]
# Out:
#            date  new_cases  new_deaths  new_tests
# 68   2020-03-08     1247.0        36.0        NaN
# 69   2020-03-09     1492.0       133.0        NaN
# 70   2020-03-10     1797.0        98.0        NaN
# 72   2020-03-12     2313.0       196.0        NaN
# 73   2020-03-13     2651.0       189.0        NaN
# ..          ...        ...         ...        ...
# 241  2020-08-28     1409.0         5.0    65135.0
# 242  2020-08-29     1460.0         9.0    64294.0
# 243  2020-08-30     1444.0         1.0    53541.0
# 244  2020-08-31     1365.0         4.0    42583.0
# 247  2020-09-03     1326.0         6.0        NaN
#
# [72 rows x 4 columns]

# %%
from IPython.display import display

# %%
with pd.option_context('display.max_rows',100):
    display(covid_info[covid_info.new_cases>1000])
# Out:
#            date  new_cases  new_deaths  new_tests
# 68   2020-03-08     1247.0        36.0        NaN
# 69   2020-03-09     1492.0       133.0        NaN
# 70   2020-03-10     1797.0        98.0        NaN
# 72   2020-03-12     2313.0       196.0        NaN
# 73   2020-03-13     2651.0       189.0        NaN
# 74   2020-03-14     2547.0       252.0        NaN
# 75   2020-03-15     3497.0       173.0        NaN
# 76   2020-03-16     2823.0       370.0        NaN
# 77   2020-03-17     4000.0       347.0        NaN
# 78   2020-03-18     3526.0       347.0        NaN
# 79   2020-03-19     4207.0       473.0        NaN
# 80   2020-03-20     5322.0       429.0        NaN
# 81   2020-03-21     5986.0       625.0        NaN
# 82   2020-03-22     6557.0       795.0        NaN
# 83   2020-03-23     5560.0       649.0        NaN
# 84   2020-03-24     4789.0       601.0        NaN
# 85   2020-03-25     5249.0       743.0        NaN
# 86   2020-03-26     5210.0       685.0        NaN
# ...

# %%
initial_tests = 935310
total_tests = initial_tests + covid_info.new_tests.sum()

# %%
positive_rate = total_cases / total_tests
positive_rate
# Out:
# 0.05206657403227681

# %%
high_ratio_df = covid_info[covid_info.new_cases/covid_info.new_tests>positive_rate]

# %%
high_ratio_df
# Out:
#            date  new_cases  new_deaths  new_tests
# 111  2020-04-20     3047.0       433.0     7841.0
# 112  2020-04-21     2256.0       454.0    28095.0
# 113  2020-04-22     2729.0       534.0    44248.0
# 114  2020-04-23     3370.0       437.0    37083.0
# 116  2020-04-25     3021.0       420.0    38676.0
# 117  2020-04-26     2357.0       415.0    24113.0
# 118  2020-04-27     2324.0       260.0    26678.0
# 120  2020-04-29     2091.0       382.0    38589.0
# 123  2020-05-02     1965.0       269.0    31231.0
# 124  2020-05-03     1900.0       474.0    27047.0
# 125  2020-05-04     1389.0       174.0    22999.0
# 128  2020-05-07     1444.0       369.0    13665.0

# %%
covid_info['positive_rate'] = covid_info.new_cases / covid_info.new_tests

# %%
covid_info
# Out:
#            date  new_cases  new_deaths  new_tests  positive_rate
# 0    2019-12-31        0.0         0.0        NaN            NaN
# 1    2020-01-01        0.0         0.0        NaN            NaN
# 2    2020-01-02        0.0         0.0        NaN            NaN
# 3    2020-01-03        0.0         0.0        NaN            NaN
# 4    2020-01-04        0.0         0.0        NaN            NaN
# ..          ...        ...         ...        ...            ...
# 243  2020-08-30     1444.0         1.0    53541.0       0.026970
# 244  2020-08-31     1365.0         4.0    42583.0       0.032055
# 245  2020-09-01      996.0         6.0    54395.0       0.018311
# 246  2020-09-02      975.0         8.0        NaN            NaN
# 247  2020-09-03     1326.0         6.0        NaN            NaN
#
# [248 rows x 5 columns]

# %%
 covid_info.drop(columns = ['positive_rate'], inplace = True)

# %%
covid_info.sort_values('new_cases',ascending = True).tail(10)
# Out:
#           date  new_cases  new_deaths  new_tests
# 86  2020-03-26     5210.0       685.0        NaN
# 90  2020-03-30     5217.0       758.0        NaN
# 85  2020-03-25     5249.0       743.0        NaN
# 80  2020-03-20     5322.0       429.0        NaN
# 83  2020-03-23     5560.0       649.0        NaN
# 88  2020-03-28     5959.0       971.0        NaN
# 89  2020-03-29     5974.0       887.0        NaN
# 81  2020-03-21     5986.0       625.0        NaN
# 87  2020-03-27     6153.0       660.0        NaN
# 82  2020-03-22     6557.0       795.0        NaN

# %%
covid_info.sort_values('new_deaths', ascending=False).head(10)
# Out:
#           date  new_cases  new_deaths  new_tests  positive_rate
# 88  2020-03-28     5959.0       971.0        NaN            NaN
# 89  2020-03-29     5974.0       887.0        NaN            NaN
# 92  2020-04-01     4053.0       839.0        NaN            NaN
# 91  2020-03-31     4050.0       810.0        NaN            NaN
# 82  2020-03-22     6557.0       795.0        NaN            NaN
# 95  2020-04-04     4585.0       764.0        NaN            NaN
# 94  2020-04-03     4668.0       760.0        NaN            NaN
# 90  2020-03-30     5217.0       758.0        NaN            NaN
# 85  2020-03-25     5249.0       743.0        NaN            NaN
# 93  2020-04-02     4782.0       727.0        NaN            NaN

# %%
covid_info.sort_values('new_cases').head(10)
# Out:
#            date  new_cases  new_deaths  new_tests  positive_rate
# 172  2020-06-20     -148.0        47.0    29875.0      -0.004954
# 0    2019-12-31        0.0         0.0        NaN            NaN
# 29   2020-01-29        0.0         0.0        NaN            NaN
# 30   2020-01-30        0.0         0.0        NaN            NaN
# 32   2020-02-01        0.0         0.0        NaN            NaN
# 33   2020-02-02        0.0         0.0        NaN            NaN
# 34   2020-02-03        0.0         0.0        NaN            NaN
# 36   2020-02-05        0.0         0.0        NaN            NaN
# 37   2020-02-06        0.0         0.0        NaN            NaN
# 38   2020-02-07        0.0         0.0        NaN            NaN

# %%
covid_info.loc[170:175]
# Out:
#            date  new_cases  new_deaths  new_tests  positive_rate
# 170  2020-06-18      328.0        43.0    32921.0       0.009963
# 171  2020-06-19      331.0        66.0    28570.0       0.011586
# 172  2020-06-20     -148.0        47.0    29875.0      -0.004954
# 173  2020-06-21      264.0        49.0    24581.0       0.010740
# 174  2020-06-22      224.0        24.0    16152.0       0.013868
# 175  2020-06-23      221.0        23.0    23225.0       0.009516

# %%
covid_info.at[172,'new_cases'] = (covid_info.at[171, 'new_cases'] + covid_info.at[173, 'new_cases'])/2

# %%
covid_info.date
# Out:
# 0      2019-12-31
# 1      2020-01-01
# 2      2020-01-02
# 3      2020-01-03
# 4      2020-01-04
#           ...
# 243    2020-08-30
# 244    2020-08-31
# 245    2020-09-01
# 246    2020-09-02
# 247    2020-09-03
# Name: date, Length: 248, dtype: object

# %%
covid_info['date'] = pd.to_datetime(covid_info.date)
covid_info.date
# Out:
# 0     2019-12-31
# 1     2020-01-01
# 2     2020-01-02
# 3     2020-01-03
# 4     2020-01-04
#          ...
# 243   2020-08-30
# 244   2020-08-31
# 245   2020-09-01
# 246   2020-09-02
# 247   2020-09-03
# Name: date, Length: 248, dtype: datetime64[ns]

# %%
covid_info['year'] = pd.DatetimeIndex(covid_info.date).year
covid_info['month'] = pd.DatetimeIndex(covid_info.date).month
covid_info['day'] = pd.DatetimeIndex(covid_info.date).day
covid_info['weekday'] = pd.DatetimeIndex(covid_info.date).weekday
covid_info
# Out:
#           date  new_cases  new_deaths  new_tests  positive_rate  year  month  \
# 0   2019-12-31        0.0         0.0        NaN            NaN  2019     12
# 1   2020-01-01        0.0         0.0        NaN            NaN  2020      1
# 2   2020-01-02        0.0         0.0        NaN            NaN  2020      1
# 3   2020-01-03        0.0         0.0        NaN            NaN  2020      1
# 4   2020-01-04        0.0         0.0        NaN            NaN  2020      1
# ..         ...        ...         ...        ...            ...   ...    ...
# 243 2020-08-30     1444.0         1.0    53541.0       0.026970  2020      8
# 244 2020-08-31     1365.0         4.0    42583.0       0.032055  2020      8
# 245 2020-09-01      996.0         6.0    54395.0       0.018311  2020      9
# 246 2020-09-02      975.0         8.0        NaN            NaN  2020      9
# 247 2020-09-03     1326.0         6.0        NaN            NaN  2020      9
#
#      day  weekday
# 0     31        1
# ...

# %%
covid_info_may = covid_info[covid_info.month == 5]
covid_info_may
# Out:
#           date  new_cases  new_deaths  new_tests  positive_rate  year  month  \
# 122 2020-05-01     1872.0       285.0    43732.0       0.042806  2020      5
# 123 2020-05-02     1965.0       269.0    31231.0       0.062918  2020      5
# 124 2020-05-03     1900.0       474.0    27047.0       0.070248  2020      5
# 125 2020-05-04     1389.0       174.0    22999.0       0.060394  2020      5
# 126 2020-05-05     1221.0       195.0    32211.0       0.037906  2020      5
# 127 2020-05-06     1075.0       236.0    37771.0       0.028461  2020      5
# 128 2020-05-07     1444.0       369.0    13665.0       0.105671  2020      5
# 129 2020-05-08     1401.0       274.0    45428.0       0.030840  2020      5
# 130 2020-05-09     1327.0       243.0    36091.0       0.036768  2020      5
# 131 2020-05-10     1083.0       194.0    31384.0       0.034508  2020      5
# 132 2020-05-11      802.0       165.0    25823.0       0.031058  2020      5
# ...

# %%
covid_info_may_data = covid_info_may[['new_cases','new_deaths','new_tests']]
covid_info_may_data
# Out:
#      new_cases  new_deaths  new_tests
# 122     1872.0       285.0    43732.0
# 123     1965.0       269.0    31231.0
# 124     1900.0       474.0    27047.0
# 125     1389.0       174.0    22999.0
# 126     1221.0       195.0    32211.0
# 127     1075.0       236.0    37771.0
# 128     1444.0       369.0    13665.0
# 129     1401.0       274.0    45428.0
# 130     1327.0       243.0    36091.0
# 131     1083.0       194.0    31384.0
# 132      802.0       165.0    25823.0
# 133      744.0       179.0    39620.0
# 134     1402.0       172.0    37049.0
# 135      888.0       195.0    41131.0
# 136      992.0       262.0    39027.0
# 137      789.0       242.0    40657.0
# 138      875.0       153.0    33505.0
# 139      675.0       145.0    26101.0
# 140      451.0        99.0    40226.0
# 141      813.0       162.0    38617.0
# 142      665.0       161.0    40644.0
# 143      642.0       156.0    42987.0
# 144      652.0       130.0    42579.0
# 145      669.0       119.0    34206.0
# ...

# %%
covid_info_total = covid_info_may_data.sum()
covid_info_total
# Out:
# new_cases       29073.0
# new_deaths       5658.0
# new_tests     1078720.0
# dtype: float64

# %%
covid_info[n.new_cases.mean()
# Out:
# 1096.6149193548388

# %%
covid_info[covid_info.weekday==6].new_cases.mean()
# Out:
# 1247.2571428571428

# %%
covid_info['total_cases'] = covid_info.new_cases.cumsum()
covid_info['total_deaths'] = covid_info.new_deaths.cumsum()
covid_info['total_tests'] = covid_info.new_tests.cumsum()
covid_info['total_tests']
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
#          ...
# 243    4182478.0
# 244    4225061.0
# 245    4279456.0
# 246          NaN
# 247          NaN
# Name: total_tests, Length: 248, dtype: float64

# %%
urlretrieve('https://gist.githubusercontent.com/aakashns/8684589ef4f266116cdce023377fc9c8/raw/99ce3826b2a9d1e6d0bde7e9e559fc8b6e9ac88b/locations.csv', 
            'locations.csv')
# Out:
# ('locations.csv', <http.client.HTTPMessage at 0x20354656190>)

# %%
locations_df = pd.read_csv('locations.csv')

# %%
locations_df
# Out:
#           location continent    population  life_expectancy  \
# 0      Afghanistan      Asia  3.892834e+07            64.83
# 1          Albania    Europe  2.877800e+06            78.57
# 2          Algeria    Africa  4.385104e+07            76.88
# 3          Andorra    Europe  7.726500e+04            83.73
# 4           Angola    Africa  3.286627e+07            61.15
# ..             ...       ...           ...              ...
# 207          Yemen      Asia  2.982597e+07            66.12
# 208         Zambia    Africa  1.838396e+07            63.89
# 209       Zimbabwe    Africa  1.486293e+07            61.49
# 210          World       NaN  7.794799e+09            72.58
# 211  International       NaN           NaN              NaN
#
#      hospital_beds_per_thousand  gdp_per_capita
# 0                         0.500        1803.987
# 1                         2.890       11803.431
# 2                         1.900       13913.839
# 3                           NaN             NaN
# ...

# %%
locations_df[locations_df.location == 'Pakistan']
# Out:
#      location continent   population  life_expectancy  \
# 145  Pakistan      Asia  220892331.0            67.27
#
#      hospital_beds_per_thousand  gdp_per_capita
# 145                         0.6        5034.708

# %%
covid_info['location'] = 'Pakistan'
covid_info
# Out:
#           date  new_cases  new_deaths  new_tests  positive_rate  year  month  \
# 0   2019-12-31        0.0         0.0        NaN            NaN  2019     12
# 1   2020-01-01        0.0         0.0        NaN            NaN  2020      1
# 2   2020-01-02        0.0         0.0        NaN            NaN  2020      1
# 3   2020-01-03        0.0         0.0        NaN            NaN  2020      1
# 4   2020-01-04        0.0         0.0        NaN            NaN  2020      1
# ..         ...        ...         ...        ...            ...   ...    ...
# 243 2020-08-30     1444.0         1.0    53541.0       0.026970  2020      8
# 244 2020-08-31     1365.0         4.0    42583.0       0.032055  2020      8
# 245 2020-09-01      996.0         6.0    54395.0       0.018311  2020      9
# 246 2020-09-02      975.0         8.0        NaN            NaN  2020      9
# 247 2020-09-03     1326.0         6.0        NaN            NaN  2020      9
#
# ...

# %%
merged_df = covid_info.merge(locations_df, on = 'location')
merged_df
# Out:
#           date  new_cases  new_deaths  new_tests  positive_rate  year  month  \
# 0   2019-12-31        0.0         0.0        NaN            NaN  2019     12
# 1   2020-01-01        0.0         0.0        NaN            NaN  2020      1
# 2   2020-01-02        0.0         0.0        NaN            NaN  2020      1
# 3   2020-01-03        0.0         0.0        NaN            NaN  2020      1
# 4   2020-01-04        0.0         0.0        NaN            NaN  2020      1
# ..         ...        ...         ...        ...            ...   ...    ...
# 243 2020-08-30     1444.0         1.0    53541.0       0.026970  2020      8
# 244 2020-08-31     1365.0         4.0    42583.0       0.032055  2020      8
# 245 2020-09-01      996.0         6.0    54395.0       0.018311  2020      9
# 246 2020-09-02      975.0         8.0        NaN            NaN  2020      9
# 247 2020-09-03     1326.0         6.0        NaN            NaN  2020      9
#
# ...

# %%
merged_df['cases_per_million'] = merged_df.total_cases * 1e6 / merged_df.population
merged_df['deaths_per_million'] = merged_df.total_deaths * 1e6 / merged_df.population
merged_df['tests_per_million'] = merged_df.total_tests * 1e6 / merged_df.population

# %%
merged_df
# Out:
#           date  new_cases  new_deaths  new_tests  positive_rate  year  month  \
# 0   2019-12-31        0.0         0.0        NaN            NaN  2019     12
# 1   2020-01-01        0.0         0.0        NaN            NaN  2020      1
# 2   2020-01-02        0.0         0.0        NaN            NaN  2020      1
# 3   2020-01-03        0.0         0.0        NaN            NaN  2020      1
# 4   2020-01-04        0.0         0.0        NaN            NaN  2020      1
# ..         ...        ...         ...        ...            ...   ...    ...
# 243 2020-08-30     1444.0         1.0    53541.0       0.026970  2020      8
# 244 2020-08-31     1365.0         4.0    42583.0       0.032055  2020      8
# 245 2020-09-01      996.0         6.0    54395.0       0.018311  2020      9
# 246 2020-09-02      975.0         8.0        NaN            NaN  2020      9
# 247 2020-09-03     1326.0         6.0        NaN            NaN  2020      9
#
# ...

# %%
result_df = merged_df[['date',
                       'new_cases', 
                       'total_cases', 
                       'new_deaths', 
                       'total_deaths', 
                       'new_tests', 
                       'total_tests', 
                       'cases_per_million', 
                       'deaths_per_million', 
                       'tests_per_million']]

# %%
result_df.to_csv('results.csv', index=None)

# %%
result_df.new_cases.plot();

# %%
result_df.loc['2020-09-01']
# Out:
# new_cases             9.960000e+02
# total_cases           2.696595e+05
# new_deaths            6.000000e+00
# total_deaths          3.548300e+04
# new_tests             5.439500e+04
# total_tests           4.279456e+06
# cases_per_million     1.220773e+03
# deaths_per_million    1.606348e+02
# tests_per_million     1.937349e+04
# Name: 2020-09-01 00:00:00, dtype: float64

# %%
result_df.new_cases.plot()
result_df.new_deaths.plot()
# Out:
# <Axes: xlabel='date'>

# %%
result_df.total_cases.plot()
result_df.total_deaths.plot();

# %%
Rate_of_death = result_df.total_deaths /result_df.total_cases
Rate_of_death.plot(title = "Death")
# Out:
# <Axes: title={'center': 'Death'}, xlabel='date'>

# %%
positive_rates = result_df.total_cases / result_df.total_tests
positive_rates.plot(title='Positive Rate');

# %%
result_df.new_cases.plot(kind='bar');
